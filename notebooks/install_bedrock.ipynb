# %%
# %pip install --no-build-isolation --force-reinstall \
    "boto3>=1.28.57" \
    "awscli>=1.29.57" \
    "botocore>=1.31.57"
# Out:
# ...
#   Using cached boto3-1.33.13-py3-none-any.whl (139 kB)
# ...
#   Using cached awscli-1.31.13-py3-none-any.whl (4.3 MB)
# ...
#   Using cached botocore-1.33.13-py3-none-any.whl (11.8 MB)
# ...
#   Using cached s3transfer-0.8.2-py3-none-any.whl (82 kB)
# ...
#   Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# ...
#   Using cached rsa-4.7.2-py3-none-any.whl (34 kB)
# ...
#   Using cached docutils-0.16-py2.py3-none-any.whl (548 kB)
# ...
#   Using cached PyYAML-6.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (736 kB)
# ...
#   Using cached colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# ...
#   Using cached urllib3-1.26.18-py2.py3-none-any.whl (143 kB)
# ...
#   Using cached python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# ...
#   Using cached pyasn1-0.5.1-py2.py3-none-any.whl (84 kB)
# ...
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# ERROR: transformers 4.30.2 has requirement huggingface-hub<1.0,>=0.14.1, but you'll have huggingface-hub 0.13.4 which is incompatible.
# ...
